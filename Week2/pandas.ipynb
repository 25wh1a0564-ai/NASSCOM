# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0564-ai/NASSCOM/blob/main/Week2/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -----------------------------------------------------------
# 🔹 1. BASIC PANDAS DATA STRUCTURES
# -----------------------------------------------------------

# Create a Series (1D labeled array with custom index)
s = pd.Series([10, 20, 30, 40], index=['a', 'b', 'c', 'd'])
print("\nSeries:")
print(s)

# Create a DataFrame (2D labeled table)
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'Salary': [50000, 60000, 70000, 80000]
}
df = pd.DataFrame(data)
print("\nDataFrame:")
print(df)
# Out:
# Series:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
#
# DataFrame:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000
# 3    David   40   80000

# %%
# -----------------------------------------------------------
# 🔹 2. CONVERT ARRAY TO DATAFRAME
# -----------------------------------------------------------

# Convert a NumPy array to a DataFrame
array = np.array([[1, 2], [3, 4], [5, 6]])
df_from_array = pd.DataFrame(array, columns=['Column1', 'Column2'])
print("\nDataFrame from NumPy array:")
print(df_from_array)
# Out:
# DataFrame from NumPy array:
#    Column1  Column2
# 0        1        2
# 1        3        4
# 2        5        6

# %%
# -----------------------------------------------------------
# 🔹 3. INDEXING & SLICING IN DATAFRAME
# -----------------------------------------------------------

# Access a row by label using loc
print("\nRow with label 1 using loc:")
print(df.loc[1])
# Out:
# Row with label 1 using loc:
# Name        Bob
# Age          30
# Salary    60000
# Name: 1, dtype: object

# %%
# Access rows by position using iloc
print("\nFirst two rows using iloc:")
print(df.iloc[0:2])
# Out:
# First two rows using iloc:
#     Name  Age  Salary
# 0  Alice   25   50000
# 1    Bob   30   60000

# %%
# Select a single column by label
print("\nSelect 'Name' column:")
print(df['Name'])

# Select multiple columns
print("\nSelect 'Name' and 'Age' columns:")
print(df[['Name', 'Age']])

# Filter rows where a condition is true
print("\nRows where Salary > 60000:")
print(df[df['Salary'] > 60000])
# Out:
# Select 'Name' column:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# Name: Name, dtype: object
#
# Select 'Name' and 'Age' columns:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40
#
# Rows where Salary > 60000:
#       Name  Age  Salary
# 2  Charlie   35   70000
# 3    David   40   80000

# %%
# -----------------------------------------------------------
# 🔹 4. DATA CLEANING
# -----------------------------------------------------------

import pandas as pd

# Create a DataFrame with missing (NaN) values
data_dirty = {
    'Name': ['Alice', 'Bob', None, 'David'],
    'Age': [25, None, 35, 40],
    'Salary': [50000, 60000, None, 80000]
}
df_dirty = pd.DataFrame(data_dirty)
print("\nOriginal Dirty DataFrame:")
print(df_dirty)
# Out:
# Original Dirty DataFrame:
#     Name   Age   Salary
# 0  Alice  25.0  50000.0
# 1    Bob   NaN  60000.0
# 2   None  35.0      NaN
# 3  David  40.0  80000.0

# %%
# Drop rows with any missing values
print("\nDrop rows with any NaN values:")
print(df_dirty.dropna())

# Fill missing values with specified values
print("\nFill missing values with a specific value:")# Detect missing values with a Boolean DataFrame
print("\nBoolean DataFrame for missing values:")
print(df_dirty.isnull())
print(df_dirty.fillna({'Name': 'Unknown', 'Age': df_dirty['Age'].mean(), 'Salary': 0}))
# Out:
# Drop rows with any NaN values:
#     Name   Age   Salary
# 0  Alice  25.0  50000.0
# 3  David  40.0  80000.0
#
# Fill missing values with a specific value:
#       Name        Age   Salary
# 0    Alice  25.000000  50000.0
# 1      Bob  33.333333  60000.0
# 2  Unknown  35.000000      0.0
# 3    David  40.000000  80000.0

# %%
# Detect missing values with a Boolean DataFrame
df_dirty = pd.DataFrame(data_dirty)
print("\nBoolean DataFrame for missing values:")
print(df_dirty.isnull())
# Out:
# Boolean DataFrame for missing values:
#     Name    Age  Salary
# 0  False  False   False
# 1  False   True   False
# 2   True  False    True
# 3  False  False   False

# %%
import pandas as pd

# Create DataFrame
data = {
    'Name': ['Ravi', 'Sita', 'Kiran', 'Anu', 'Rahul'],
    'Age': [25, 35, 28, 40, 32],
    'Salary': [30000, 45000, 35000, 60000, 50000]
}

df = pd.DataFrame(data)

# Add Bonus column
df['Bonus'] = df['Salary'] * 0.1
print("DataFrame with Bonus:")
print(df)

# Rename Salary column
df_renamed = df.rename(columns={'Salary': 'BaseSalary'})
print("\nRenamed DataFrame:")
print(df_renamed)

# Sort by Age in descending order
print("\nSorted by Age:")
print(df.sort_values(by='Age', ascending=False))

# Create AgeGroup
df['AgeGroup'] = df['Age'] > 30

# Average salary by AgeGroup
print("\nAverage Salary by AgeGroup:")
print(df.groupby('AgeGroup')['Salary'].mean())
# Out:
# DataFrame with Bonus:
#     Name  Age  Salary   Bonus
# 0   Ravi   25   30000  3000.0
# 1   Sita   35   45000  4500.0
# 2  Kiran   28   35000  3500.0
# 3    Anu   40   60000  6000.0
# 4  Rahul   32   50000  5000.0
#
# Renamed DataFrame:
#     Name  Age  BaseSalary   Bonus
# 0   Ravi   25       30000  3000.0
# 1   Sita   35       45000  4500.0
# 2  Kiran   28       35000  3500.0
# 3    Anu   40       60000  6000.0
# 4  Rahul   32       50000  5000.0
#
# Sorted by Age:
#     Name  Age  Salary   Bonus
# 3    Anu   40   60000  6000.0
# 1   Sita   35   45000  4500.0
# 4  Rahul   32   50000  5000.0
# 2  Kiran   28   35000  3500.0
# 0   Ravi   25   30000  3000.0
#
# Average Salary by AgeGroup:
# AgeGroup
# False    32500.000000
# True     51666.666667
# Name: Salary, dtype: float64

# %%
# Rename columns using rename()
print("\nRename columns:")
df_renamed = df.rename(columns={'Salary': 'BaseSalary'})
print(df_renamed)
# Out:
# Rename columns:
#     Name  Age  BaseSalary   Bonus  AgeGroup
# 0   Ravi   25       30000  3000.0     False
# 1   Sita   35       45000  4500.0      True
# 2  Kiran   28       35000  3500.0     False
# 3    Anu   40       60000  6000.0      True
# 4  Rahul   32       50000  5000.0      True

# %%
# Sort rows by a column in descending order
print("\nSort by Age descending:")
print(df.sort_values(by='Age', ascending=False))

# Group by a derived boolean column and calculate mean
print("\nGroup by operation (average salary by age > 30 or not):")
df['AgeGroup'] = df['Age'] > 30
print(df.groupby('AgeGroup')['Salary'].mean())
# Out:
# Sort by Age descending:
#     Name  Age  Salary   Bonus  AgeGroup
# 3    Anu   40   60000  6000.0      True
# 1   Sita   35   45000  4500.0      True
# 4  Rahul   32   50000  5000.0      True
# 2  Kiran   28   35000  3500.0     False
# 0   Ravi   25   30000  3000.0     False
#
# Group by operation (average salary by age > 30 or not):
# AgeGroup
# False    32500.000000
# True     51666.666667
# Name: Salary, dtype: float64

# %%
import pandas as pd
import numpy as np

# Create a synthetic DataFrame for practice with random data
np.random.seed(1)

num_rows = 10

df_synth = pd.DataFrame({
    'ID': np.arange(1, num_rows + 1),
    'Score': np.random.randint(50, 100, size=num_rows),
    'Passed': np.random.choice([True, False], size=num_rows)
})

print("\nSynthetic DataFrame:")
print(df_synth)
# Out:
# Synthetic DataFrame:
#    ID  Score  Passed
# 0   1     87   False
# 1   2     93    True
# 2   3     62   False
# 3   4     58   False
# 4   5     59    True
# 5   6     61    True
# 6   7     55   False
# 7   8     65    True
# 8   9     50    True
# 9  10     66    True

# %%
# Filter rows based on a condition
print("\nStudents who passed:")
print(df_synth[df_synth['Passed'] == True])

# Calculate mean for filtered rows
print("\nAverage score of failed students:")
print(df_synth[df_synth['Passed'] == False]['Score'].mean())
# Out:
# Students who passed:
#    ID  Score  Passed
# 1   2     93    True
# 4   5     59    True
# 5   6     61    True
# 7   8     65    True
# 8   9     50    True
# 9  10     66    True
#
# Average score of failed students:
# 65.5

# %%
# -----------------------------------------------------------
# 🔹 7. INSPECTING DATAFRAME STRUCTURE
# -----------------------------------------------------------

# Get concise summary of DataFrame including types and non-null counts
print("\nDataFrame info:")
df.info()

# Get basic statistics of numerical columns
print("\nDataFrame describe:")
print(df.describe())
# Out:
# DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      5 non-null      object
#  1   Age       5 non-null      int64
#  2   Salary    5 non-null      int64
#  3   Bonus     5 non-null      float64
#  4   AgeGroup  5 non-null      bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 297.0+ bytes
#
# DataFrame describe:
#             Age        Salary        Bonus
# count   5.00000      5.000000     5.000000
# mean   32.00000  44000.000000  4400.000000
# std     5.87367  11937.336386  1193.733639
# min    25.00000  30000.000000  3000.000000
# 25%    28.00000  35000.000000  3500.000000
# 50%    32.00000  45000.000000  4500.000000
# 75%    35.00000  50000.000000  5000.000000
# max    40.00000  60000.000000  6000.000000

# %%
# Check data types of columns
print("\nData types of each column:")
print(df.dtypes)

# View top rows
print("\nFirst 3 rows:")
print(df.head(3))

# View bottom rows
print("\nLast 2 rows:")
print(df.tail(2))
# Out:
# Data types of each column:
# Name         object
# Age           int64
# Salary        int64
# Bonus       float64
# AgeGroup       bool
# dtype: object
#
# First 3 rows:
#     Name  Age  Salary   Bonus  AgeGroup
# 0   Ravi   25   30000  3000.0     False
# 1   Sita   35   45000  4500.0      True
# 2  Kiran   28   35000  3500.0     False
#
# Last 2 rows:
#     Name  Age  Salary   Bonus  AgeGroup
# 3    Anu   40   60000  6000.0      True
# 4  Rahul   32   50000  5000.0      True

# %%
# -----------------------------------------------------------
# 🔹 8. STATISTICAL & PROBABILITY FUNCTIONS IN PANDAS
# -----------------------------------------------------------

# Compute central tendency measures
print("\nMean Age:", df['Age'].mean())
print("Median Salary:", df['Salary'].median())
print("Mode of Bonus:")
print(df['Bonus'].mode())

# Compute spread measures
print("Standard Deviation of Salary:", df['Salary'].std())
print("Variance of Salary:", df['Salary'].var())
# Out:
# Mean Age: 32.0
# Median Salary: 45000.0
# Mode of Bonus:
# 0    3000.0
# 1    3500.0
# 2    4500.0
# 3    5000.0
# 4    6000.0
# Name: Bonus, dtype: float64
# Standard Deviation of Salary: 11937.336386313322
# Variance of Salary: 142500000.0

# %%
# Correlation and Covariance between columns
print("\nCorrelation between Age and Salary:")
print(df[['Age', 'Salary']].corr())

print("\nCovariance between Age and Salary:")
print(df[['Age', 'Salary']].cov())

# Frequency of values
print("\nValue counts for AgeGroup:")
print(df['AgeGroup'].value_counts())
# Out:
# Correlation between Age and Salary:
#              Age    Salary
# Age     1.000000  0.944863
# Salary  0.944863  1.000000
#
# Covariance between Age and Salary:
#             Age       Salary
# Age        34.5      66250.0
# Salary  66250.0  142500000.0
#
# Value counts for AgeGroup:
# AgeGroup
# True     3
# False    2
# Name: count, dtype: int64

# %%
# Cumulative statistics
print("\nCumulative sum of Salary:")
print(df['Salary'].cumsum())

print("\nCumulative max of Salary:")
print(df['Salary'].cummax())

# Rank values
print("\nRank of Salary:")
print(df['Salary'].rank())

# Quantile-based binning
print("\nQuantiles of Salary:")
print(df['Salary'].quantile([0.25, 0.5, 0.75]))
# Out:
# Cumulative sum of Salary:
# 0     30000
# 1     75000
# 2    110000
# 3    170000
# 4    220000
# Name: Salary, dtype: int64
#
# Cumulative max of Salary:
# 0    30000
# 1    45000
# 2    45000
# 3    60000
# 4    60000
# Name: Salary, dtype: int64
#
# Rank of Salary:
# 0    1.0
# 1    3.0
# 2    2.0
# 3    5.0
# 4    4.0
# Name: Salary, dtype: float64
#
# Quantiles of Salary:
# 0.25    35000.0
# 0.50    45000.0
# 0.75    50000.0
# Name: Salary, dtype: float64
